# %% [markdown]
# ## Los datos
#
# El equipo de la universidad ya a probado mas de 100 muestras ([source](https://archive.ics.uci.edu/ml/datasets/concrete+compressive+strength)):
#
# #### Datos de resistencia a la comprensión.
# - "cement" - Portland cement in kg/m3
# - "slag" - Blast furnace slag in kg/m3
# - "fly_ash" - Fly ash in kg/m3
# - "water" - Water in liters/m3
# - "superplasticizer" - Superplasticizer additive in kg/m3
# - "coarse_aggregate" - Coarse aggregate (gravel) in kg/m3
# - "fine_aggregate" - Fine aggregate (sand) in kg/m3
# - "age" - Age of the sample in days
# - "strength" - Concrete compressive strength in megapascals (MPa)
#
# ***Acknowledgments**: I-Cheng Yeh, "Modeling of strength of high-performance concrete using artificial neural networks," Cement and Concrete Research, Vol. 28, No. 12, pp. 1797-1808 (1998)*.

# %%
import pandas as pd
df = pd.read_csv('concrete_data.csv')
df.head()
# Out:
#    cement   slag  fly_ash  water  superplasticizer  coarse_aggregate  \
# 0   540.0    0.0      0.0  162.0               2.5            1040.0
# 1   540.0    0.0      0.0  162.0               2.5            1055.0
# 2   332.5  142.5      0.0  228.0               0.0             932.0
# 3   332.5  142.5      0.0  228.0               0.0             932.0
# 4   198.6  132.4      0.0  192.0               0.0             978.4
#
#    fine_aggregate  age   strength
# 0           676.0   28  79.986111
# 1           676.0   28  61.887366
# 2           594.0  270  40.269535
# 3           594.0  365  41.052780
# 4           825.5  360  44.296075

# %% [markdown]
# Tenemos que proprcionar una fórmula que estime la resistencia a la compresión. Incluyendo:
#
#
# 1. La resistencia promedio de las muestras de concreto a los 1, 7, 14, y 28 dias de edad.
# 2. Los coeficientes $\beta_{0}$, $\beta_{1}$ ... $\beta_{8}$, para usar en la siguiente formula:
#
# $$ Concrete \ Strength = \beta_{0} \ + \ \beta_{1}*cement \ + \ \beta_{2}*slag \ + \ \beta_{3}*fly \ ash  \ + \ \beta_{4}*water \ + $$
# $$ \beta_{5}*superplasticizer \ + \ \beta_{6}*coarse \ aggregate \ + \ \beta_{7}*fine \ aggregate \ + \ \beta_{8}*age $$
